# %% [markdown]
# # Carga de Dataset de Clientes con Pandas
# Este cuaderno fue generado para cargar y explorar el dataset `DD_clientes_dataset.csv` en un entorno de Anaconda (Jupyter Notebook).

# %%
import pandas as pd

# Ruta absoluta al archivo CSV
ruta_archivo = '/Users/kevizapatafigueroa/Downloads/DD_clientes_dataset.csv'

# Cargar el dataset usando pandas
df_clientes = pd.read_csv(ruta_archivo)

# %%
# Mostrar las primeras 5 filas para verificar la carga correcta
df_clientes.head()

# %%
# Ver información general del dataset (columnas, tipos de datos, valores nulos)
df_clientes.info()
